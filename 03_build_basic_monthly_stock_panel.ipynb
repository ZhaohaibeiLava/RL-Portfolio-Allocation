# %% [markdown]
# # Build Basic Monthly Stock Panel
#
# This notebook runs the production CLI script `build_basic_monthly_stock_panel.py` so notebook and command-line executions use the same implementation.

# %%
# %run ./build_basic_monthly_stock_panel.py --indir data/raw --outdir data/panel
# Out:
# 2026-04-28 16:12:09 INFO build_basic_monthly_stock_panel - Using pyarrow 20.0.0 for parquet output.
# 2026-04-28 16:12:09 WARNING build_basic_monthly_stock_panel - Preferred CRSP input /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/raw/crsp_monthly_ever_sp500.parquet was not found; using fallback /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/raw/crsp_monthly_sp500_panel.parquet. Next-month targets may be incomplete for stocks that exit the S&P 500 after month t.
# 2026-04-28 16:12:09 INFO build_basic_monthly_stock_panel - Loading membership from /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/raw/sp500_membership_monthly.parquet.
# 2026-04-28 16:12:09 INFO build_basic_monthly_stock_panel - Loading crsp from /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/raw/crsp_monthly_sp500_panel.parquet.
# 2026-04-28 16:12:09 INFO build_basic_monthly_stock_panel - Loading ff3 from /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/raw/ff3_monthly.parquet.
# 2026-04-28 16:12:09 WARNING build_basic_monthly_stock_panel - CRSP has 408 exact duplicate rows; dropping exact duplicates before panel construction.
# 2026-04-28 16:12:10 INFO build_basic_monthly_stock_panel - Common-share filter shrcd in {10, 11}: kept 139255 of 150492 rows.
# 2026-04-28 16:12:10 INFO build_basic_monthly_stock_panel - Exchange filter exchcd in {1, 2, 3}: kept 139179 of 139255 rows.
# 2026-04-28 16:12:10 INFO build_basic_monthly_stock_panel - Saving full panel to /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/panel/monthly_stock_panel_basic_full.parquet.
# 2026-04-28 16:12:10 INFO build_basic_monthly_stock_panel - Saving model panel to /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/panel/monthly_stock_panel_basic_model.parquet.
# 2026-04-28 16:12:10 INFO build_basic_monthly_stock_panel - Done. Full panel rows: 139,179; model panel rows: 127,751; output directory: /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/panel.
