# %% [markdown]
# # Build Basic Monthly Stock Panel
#
# This notebook runs the production CLI script `scripts/build_basic_monthly_stock_panel.py` so notebook and command-line executions use the same implementation.

# %%
# %run ./scripts/build_basic_monthly_stock_panel.py --indir data/raw --outdir data/panel
