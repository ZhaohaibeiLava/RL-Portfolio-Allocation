# %% [markdown]
# # Run Fama-MacBeth Baseline V1
#
# This notebook runs the production CLI script `run_fm_baseline_v1.py` so notebook and command-line executions share the same implementation.

# %%
# %run ./run_fm_baseline_v1.py --indir data/panel --outdir data/prediction
# Out:
# 2026-04-28 17:06:22 INFO run_fm_baseline_v1 - Using pyarrow 20.0.0 for parquet output.
# 2026-04-28 17:06:22 INFO run_fm_baseline_v1 - Loading model panel from /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/panel/monthly_stock_panel_basic_model.parquet.
# 2026-04-28 17:06:22 INFO run_fm_baseline_v1 - Kept 127751 of 127751 rows after dropping missing target/features.
# 2026-04-28 17:06:22 INFO run_fm_baseline_v1 - Estimated monthly betas for 288 months.
# 2026-04-28 17:06:22 INFO run_fm_baseline_v1 - Produced 100,092 out-of-sample predictions across 228 months.
# 2026-04-28 17:06:23 INFO run_fm_baseline_v1 - Saving monthly betas.
# 2026-04-28 17:06:23 INFO run_fm_baseline_v1 - Saving out-of-sample predictions.
# 2026-04-28 17:06:23 INFO run_fm_baseline_v1 - Done. Forecast months: 228; predictions: 100,092; output directory: /Users/lava/Documents/Research/GeorgeMichailidis/portfolio_allocation_rl/data/prediction.
