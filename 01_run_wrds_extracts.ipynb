# %%
# WRDS Extract 01: S&P 500 Membership
# %run ./wrds_extract_membership.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 02: CRSP Monthly Panel for S&P 500 Members
# %run ./wrds_extract_crsp_panel.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 03: Fama-French Monthly Factors
# %run ./wrds_extract_ff3.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 04: SPY Data from WRDS
# %run ./fetch_spy_from_wrds.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/benchmark
# Out:
# 2026-04-30 22:34:23 INFO fetch_spy_from_wrds - Using pyarrow 20.0.0 for parquet output.
# 2026-04-30 22:34:23 INFO fetch_spy_from_wrds - Connecting to WRDS.
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# 2026-04-30 22:35:34 INFO fetch_spy_from_wrds - Using CRSP names table crsp.msenames.
# Done
# 2026-04-30 22:35:34 INFO fetch_spy_from_wrds - Found 7 CRSP name rows for ticker SPY.
# 2026-04-30 22:35:34 INFO fetch_spy_from_wrds - Fetching crsp.msf rows for permno 84398.
# 2026-04-30 22:35:35 INFO fetch_spy_from_wrds - Fetched 300 monthly rows.
# 2026-04-30 22:35:35 INFO fetch_spy_from_wrds - Wrote raw monthly data to data/benchmark/spy_monthly_raw.parquet.
# 2026-04-30 22:35:35 INFO fetch_spy_from_wrds - Wrote clean monthly benchmark to data/benchmark/spy_monthly.parquet.
# ...

# %%
# WRDS Extract 05: Sanity checks for extracted raw data
# %run ./sanity_check_wrds_extract.py --project-root . --raw-dir data/raw --benchmark-dir data/benchmark --outdir data/sanity_checks
