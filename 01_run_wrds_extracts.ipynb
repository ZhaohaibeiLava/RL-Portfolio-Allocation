# %%
# WRDS Extract 01: S&P 500 Membership
# %run ./scripts/wrds_extract_membership.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 02: CRSP Monthly Panel for S&P 500 Members
# %run ./scripts/wrds_extract_crsp_panel.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 03: Fama-French Monthly Factors
# %run ./scripts/wrds_extract_ff3.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/raw

# %%
# WRDS Extract 04: SPY Data from WRDS
# %run ./scripts/fetch_spy_from_wrds.py --start-date 2000-01-01 --end-date 2025-12-31 --outdir data/benchmark

# %%
# WRDS Extract 05: Sanity checks for extracted raw data
# %run ./scripts/sanity_check_wrds_extract.py --project-root . --raw-dir data/raw --benchmark-dir data/benchmark --outdir data/sanity_checks
